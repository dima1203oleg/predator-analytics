# %%
# Встановлення залежностей для Kaggle та локального Jupyter
# %pip install -q fastapi uvicorn sqlalchemy aiosqlite python-jose passlib bcrypt psutil nest_asyncio
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # PREDATOR Analytics v65.0-ELITE: Kaggle Backend Node
#
# **CPU-Only | Max RAM: 30GB | SQLite + RBAC + Filters + CSV**
#
# ### Features v65.0:
# - SQLite database with 25 Ukrainian companies
# - JWT auth (admin/client/vip)
# - RBAC roles
# - Company filtering & sorting
# - CSV import/export
# - WebSocket real-time dashboard
# - Cloudflared quick tunnel

# %%
# Ініціалізація бази даних
import nest_asyncio
nest_asyncio.apply()

await init_database()
print("База даних ініціалізована та заповнена seed даними.")
# Out:
# (trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/Users/Shared/Predator_60/.venv/lib/python3.12/site-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# База даних ініціалізована та заповнена seed даними.

# %%
if __name__ == "__main__":
    import uvicorn
    # Запуск uvicorn в окремому потоці для Jupyter/Kaggle
    import threading
    
    def run_server():
        uvicorn.run(app, host="0.0.0.0", port=8000)
    
    # Запуск cloudflared тунелю (тільки в Kaggle)
    threading.Thread(target=run_cloudflared_tunnel, args=(8000,), daemon=True).start()
    
    # Запуск OODA Loop
    ooda.start()
    
    # Запуск сервера
    print("Запуск сервера на порту 8000...")
    print("Cloudflared тунель запускається в окремому потоці...")
    run_server()
# Out:
# Завантаження cloudflared...Запуск сервера на порту 8000...
# Cloudflared тунель запускається в окремому потоці...
#
# ERROR: cloudflared не завантажився
# /bin/sh: wget: command not found
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 18
#      14
#      15     # Запуск сервера
#      16     print("Запуск сервера на порту 8000...")
#      17     print("Cloudflared тунель запускається в окремому потоці...")
# ---> 18     run_server()
#
# Cell In[9], line 7, in run_server()
#       6     def run_server():
# ----> 7         uvicorn.run(app, host="0.0.0.0", port=8000)
#
# File /Users/Shared/Predator_60/.venv/lib/python3.12/site-packages/uvicorn/main.py:606, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, limit_max_requests_jitter, timeout_keep_alive, timeout_graceful_shutdown, timeout_worker_healthcheck, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     604         Multiprocess(config, target=server.run, sockets=[sock]).run()
#     605     else:
# --> 606         server.run()
#     607 except KeyboardInterrupt:
#     608     pass  # pragma: full coverage
#
# File /Users/Shared/Predator_60/.venv/lib/python3.12/site-packages/uvicorn/server.py:75, in Server.run(self, sockets)
#      74 def run(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 75     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#
# File /opt/homebrew/Cellar/python@3.12/3.12.12_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

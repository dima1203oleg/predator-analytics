# %%
# Встановлення залежностей для Kaggle та локального Jupyter
# %pip install -q fastapi uvicorn sqlalchemy aiosqlite python-jose passlib bcrypt psutil nest_asyncio
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # PREDATOR Analytics v65.0-ELITE: Kaggle Backend Node
#
# **CPU-Only | Max RAM: 30GB | SQLite + RBAC + Filters + CSV**
#
# ### Features v65.0:
# - SQLite database with 25 Ukrainian companies
# - JWT auth (admin/client/vip)
# - RBAC roles
# - Company filtering & sorting
# - CSV import/export
# - WebSocket real-time dashboard
# - Cloudflared quick tunnel

# %%
# Ініціалізація бази даних
import nest_asyncio
nest_asyncio.apply()

await init_database()
print("База даних ініціалізована та заповнена seed даними.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 # Ініціалізація бази даних
#       2 import nest_asyncio
#       3 nest_asyncio.apply()
#       4
# ----> 5 await init_database()
#       6 print("База даних ініціалізована та заповнена seed даними.")
#
# NameError: name 'init_database' is not defined

# %%
if __name__ == "__main__":
    import uvicorn
    # Запуск uvicorn в окремому потоці для Jupyter/Kaggle
    import threading
    
    def run_server():
        uvicorn.run(app, host="0.0.0.0", port=8000)
    
    # Запуск cloudflared тунелю (тільки в Kaggle)
    threading.Thread(target=run_cloudflared_tunnel, args=(8000,), daemon=True).start()
    
    # Запуск OODA Loop
    ooda.start()
    
    # Запуск сервера
    print("Запуск сервера на порту 8000...")
    print("Cloudflared тунель запускається в окремому потоці...")
    run_server()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       6     def run_server():
#       7         uvicorn.run(app, host="0.0.0.0", port=8000)
#       8
#       9     # Запуск cloudflared тунелю (тільки в Kaggle)
# ---> 10     threading.Thread(target=run_cloudflared_tunnel, args=(8000,), daemon=True).start()
#      11
#      12     # Запуск OODA Loop
#      13     ooda.start()
#
# NameError: name 'run_cloudflared_tunnel' is not defined
